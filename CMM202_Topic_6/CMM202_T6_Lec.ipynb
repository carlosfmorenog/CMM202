# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfmorenog/CMM202/blob/master/CMM202_Topic_6/CMM202_T6_Lec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CMM202 Topic 6: Time Series Data + Bar Chart Race

# %% [markdown]
# ## Lecture objectives

# %% [markdown]
# 1) Understand the concept of time series data and what does it imply

# %% [markdown]
# 2) Process time series datasets into effective dataframes

# %% [markdown]
# 3) Produce a bar chart race

# %% [markdown]
# ## What is Time Series Data (TSD)?

# %% [markdown]
# Simply put, datasets that describe/contain data which varies over time

# %% [markdown]
# They are usually characterised by a fixed and constant aggregation of data
#
#     Readings from sensors in the industry
#     Coronavirus cases
#     Trends in economics

# %% [markdown]
# The art of using these datasets resides in knowing how to shape them and using the right features

# %% [markdown]
# To practice, we will use the dataset called `bitcoin.csv`

# %% [markdown]
# This data set contains the price of the Bitcoin cryptocurrency on the US-based exchange Gemini, minute-by-minute for all of 2017

# %%
import pandas as pd
import numpy as np
bitcoin = pd.read_csv('https://www.dropbox.com/s/kxjc92oia6gcoy8/bitcoin.csv?raw=1', index_col=0)
bitcoin
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2017-01-01 00:00:00    974.55    974.55    974.55    974.55   0.000000
# 2017-01-01 00:01:00    974.55    974.55    974.55    974.55   0.000000
# 2017-01-01 00:02:00    974.55    974.55    970.00    970.00   0.417679
# 2017-01-01 00:03:00    970.00    970.00    970.00    970.00   0.000514
# 2017-01-01 00:04:00    970.00    970.00    970.00    970.00   0.000000
# ...                       ...       ...       ...       ...        ...
# 2017-12-31 23:55:00  13782.87  13782.87  13771.00  13771.00   1.657980
# 2017-12-31 23:56:00  13771.00  13775.00  13770.95  13775.00   7.538428
# 2017-12-31 23:57:00  13775.00  13815.37  13775.00  13815.37  18.437304
# 2017-12-31 23:58:00  13815.37  13825.00  13815.37  13825.00   3.547593
# 2017-12-31 23:59:00  13825.00  13825.00  13804.68  13820.26   2.610719
#
# [525600 rows x 5 columns]

# %% [markdown]
# Note that the `Date` column contains entries formatted as a date-time such as `2017-01-01 00:00:00`

# %% [markdown]
# First, let's check the type of this data by examining the first item

# %%
first_index_value = bitcoin.index[0]
print(first_index_value)
print(type(first_index_value))
# Out:
# 2017-01-01 00:00:00
# <class 'str'>

# %% [markdown]
# We can avoid this in one go by parsing the dates when loading

# %%
bitcoin = pd.read_csv('https://www.dropbox.com/s/kxjc92oia6gcoy8/bitcoin.csv?raw=1', 
                      parse_dates=['Date'], index_col=0)
bitcoin
# Out:
#                          Open      High       Low     Close     Volume
# Date
# 2017-01-01 00:00:00    974.55    974.55    974.55    974.55   0.000000
# 2017-01-01 00:01:00    974.55    974.55    974.55    974.55   0.000000
# 2017-01-01 00:02:00    974.55    974.55    970.00    970.00   0.417679
# 2017-01-01 00:03:00    970.00    970.00    970.00    970.00   0.000514
# 2017-01-01 00:04:00    970.00    970.00    970.00    970.00   0.000000
# ...                       ...       ...       ...       ...        ...
# 2017-12-31 23:55:00  13782.87  13782.87  13771.00  13771.00   1.657980
# 2017-12-31 23:56:00  13771.00  13775.00  13770.95  13775.00   7.538428
# 2017-12-31 23:57:00  13775.00  13815.37  13775.00  13815.37  18.437304
# 2017-12-31 23:58:00  13815.37  13825.00  13815.37  13825.00   3.547593
# 2017-12-31 23:59:00  13825.00  13825.00  13804.68  13820.26   2.610719
#
# [525600 rows x 5 columns]

# %% [markdown]
# If we check the column now, it is marked as `Timestamp`

# %%
first_index_value = bitcoin.index[0]
print(first_index_value)
print(type(first_index_value))
# Out:
# 2017-01-01 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# ## Exploring TSD

# %% [markdown]
# This data set contains the following columns:

# %% [markdown]
# Price Data:
#
# - Open - The price of the commodity *(bitcoin)* at the **start** of the time period *(minute)*
# - High - The **highest** value the price reached during the time period
# - Low - The **lowest** value the price reached during the time period
# - Close - The price at the **end** of the time period

# %% [markdown]
# Trade Data:
#
# - Volume - The total amount of the commodity bought/sold in the time period

# %% [markdown]
# Other time series data sets will have other columns, but this is common for financial data

# %% [markdown]
# Even though the index is stored as `Timestamp`, we can retrieve rows by querying with a string

# %% [markdown]
# For example during the minute `2017-05-27 19:30:00`, we can query using `2017-05-27 19:30:00` which matches the data

# %% [markdown]
# However, since the data set has only minute-by-minute data, the seconds don't matter, so we can exclude the seconds in our query and search for `2017-05-27 19:30`

# %%
bitcoin.loc['2017-05-27 19:30']
# Out:
# Open      2144.68000
# High      2144.68000
# Low       2141.26000
# Close     2142.53000
# Volume       0.05406
# Name: 2017-05-27 19:30:00, dtype: float64

# %% [markdown]
# The price started this minute at `2144.68` USD, dropped to `2142.53` USD at the end of the minute

# %% [markdown]
# During this time the minimum value was `2141.26` USD and the maximum value was `2144.68` USD

# %% [markdown]
# `0.05406` bitcoin was bought/sold during this minute

# %% [markdown]
# Let's check the next minute `2017-05-27 19:31`

# %%
bitcoin.loc['2017-05-27 19:31']
# Out:
# Open      2142.5300
# High      2142.5300
# Low       2141.2700
# Close     2141.2700
# Volume       0.2069
# Name: 2017-05-27 19:31:00, dtype: float64

# %% [markdown]
# The previous minute **closed** at `2142.53` USD and this minute **opened** at `2142.53` USD

# %% [markdown]
# This is expected since the end of one minute is the same as the start of the next minute!

# %% [markdown]
# If we want to check the open and close price for the **day**, we could check the open price for the first minute and close price for the last minute

# %%
print(bitcoin.loc['2017-05-27 00:00'])
print(bitcoin.loc['2017-05-27 23:59'])
# Out:
# Open      2267.370000
# High      2267.370000
# Low       2267.360000
# Close     2267.370000
# Volume      10.822462
# Name: 2017-05-27 00:00:00, dtype: float64
# Open      2096.77
# High      2096.77
# Low       2096.77
# Close     2096.77
# Volume       0.00
# Name: 2017-05-27 23:59:00, dtype: float64

# %% [markdown]
# We can select an interval of time the same way we do with numbers

# %% [markdown]
# With the following code, we select all of the values in May of 2017

# %%
bitcoin[(bitcoin.index >= '2017-05') & (bitcoin.index < '2017-06')]
# Out:
#                         Open     High      Low    Close     Volume
# Date
# 2017-05-01 00:00:00  1362.63  1362.63  1359.05  1359.05   0.129530
# 2017-05-01 00:01:00  1359.05  1359.05  1359.05  1359.05   0.015945
# 2017-05-01 00:02:00  1359.05  1359.05  1359.05  1359.05   0.430274
# 2017-05-01 00:03:00  1359.05  1359.05  1359.05  1359.05   0.024931
# 2017-05-01 00:04:00  1359.05  1359.05  1359.05  1359.05   0.000000
# ...                      ...      ...      ...      ...        ...
# 2017-05-31 23:55:00  2301.80  2301.80  2301.80  2301.80   0.000000
# 2017-05-31 23:56:00  2301.80  2301.80  2301.80  2301.80   0.065392
# 2017-05-31 23:57:00  2301.80  2301.80  2301.80  2301.80   0.000000
# 2017-05-31 23:58:00  2301.80  2301.80  2301.80  2301.80   0.000000
# 2017-05-31 23:59:00  2301.80  2303.62  2301.80  2303.62  13.587863
#
# [44640 rows x 5 columns]

# %% [markdown]
# Selecting all of the values for 1st May before noon

# %%
bitcoin[(bitcoin.index >= '2017-05-01') & (bitcoin.index < '2017-05-01 12:00')]
# Out:
#                         Open     High      Low    Close     Volume
# Date
# 2017-05-01 00:00:00  1362.63  1362.63  1359.05  1359.05   0.129530
# 2017-05-01 00:01:00  1359.05  1359.05  1359.05  1359.05   0.015945
# 2017-05-01 00:02:00  1359.05  1359.05  1359.05  1359.05   0.430274
# 2017-05-01 00:03:00  1359.05  1359.05  1359.05  1359.05   0.024931
# 2017-05-01 00:04:00  1359.05  1359.05  1359.05  1359.05   0.000000
# ...                      ...      ...      ...      ...        ...
# 2017-05-01 11:55:00  1376.43  1376.43  1376.40  1376.43   0.064194
# 2017-05-01 11:56:00  1376.43  1377.36  1376.43  1377.36   0.013068
# 2017-05-01 11:57:00  1377.36  1377.36  1377.35  1377.35   0.023829
# 2017-05-01 11:58:00  1377.35  1378.25  1377.35  1378.24  17.260743
# 2017-05-01 11:59:00  1378.24  1378.24  1378.24  1378.24   0.000000
#
# [720 rows x 5 columns]

# %% [markdown]
# ## Calculations with TSD

# %% [markdown]
# We may want to calculate other values such as taking the middle value between the `Low` and `High` values, this will allow us to calculate an estimate for the value of the bitcoin traded

# %% [markdown]
# It will only be an **estimate** since we don't have the exact list of trades available in this dataset!

# %% [markdown]
# We can perform calculations on the columns in exactly the same we we have with any other data set before

# %%
bitcoin['Middle'] = (bitcoin['High'] + bitcoin['Low']) / 2
bitcoin['USD Volume'] = bitcoin['Middle'] * bitcoin['Volume']
bitcoin
# Out:
#                          Open      High  ...     Middle     USD Volume
# Date                                     ...
# 2017-01-01 00:00:00    974.55    974.55  ...    974.550       0.000000
# 2017-01-01 00:01:00    974.55    974.55  ...    974.550       0.000000
# 2017-01-01 00:02:00    974.55    974.55  ...    972.275     406.099132
# 2017-01-01 00:03:00    970.00    970.00  ...    970.000       0.498755
# 2017-01-01 00:04:00    970.00    970.00  ...    970.000       0.000000
# ...                       ...       ...  ...        ...            ...
# 2017-12-31 23:55:00  13782.87  13782.87  ...  13776.935   22841.878972
# 2017-12-31 23:56:00  13771.00  13775.00  ...  13772.975  103826.583413
# 2017-12-31 23:57:00  13775.00  13815.37  ...  13795.185  254346.017926
# 2017-12-31 23:58:00  13815.37  13825.00  ...  13820.185   49028.397646
# 2017-12-31 23:59:00  13825.00  13825.00  ...  13814.840   36066.660297
#
# [525600 rows x 7 columns]

# %% [markdown]
# ## Resampling TSD

# %% [markdown]
# Sometimes we are interested in sampling the in larger chunks than it is presented

# %% [markdown]
# For instance, this data has one line per **minute**; we may want data for **days** instead

# %% [markdown]
# The method to resample the data in Python is called `resample`, and takes a time period as an argument

# %% [markdown]
# For example, `1D` means 1 day (you can see more options [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.resample.html))

# %%
# Not very useful output, right?
bitcoin.resample('1D')

# %% [markdown]
# If we call the `mean` method, it will average out the values of this new object by day

# %%
bitcoin.resample('1D').mean()
# Out:
#                     Open          High  ...        Middle     USD Volume
# Date                                    ...
# 2017-01-01    980.776378    980.898135  ...    980.780766     737.218302
# 2017-01-02   1016.424132   1016.618785  ...   1016.433052    1025.061363
# 2017-01-03   1023.624340   1023.743431  ...   1023.629042    1636.278683
# 2017-01-04   1082.933979   1083.422104  ...   1082.986267    2464.408073
# 2017-01-05   1056.542243   1057.577083  ...   1056.494177    4165.407749
# ...                  ...           ...  ...           ...            ...
# 2017-12-27  15639.538896  15655.889035  ...  15638.903309   99412.047834
# 2017-12-28  14261.058215  14285.193507  ...  14261.282264  108742.624129
# 2017-12-29  14535.871354  14549.550931  ...  14535.998903   64443.408129
# 2017-12-30  13476.331806  13494.028972  ...  13474.107462   80474.783127
# 2017-12-31  13274.262319  13285.760785  ...  13274.163288   75170.569715
#
# [365 rows x 7 columns]

# %% [markdown]
# The method takes the values in the column `Volume` and rows `2017-01-01 00:00` to `2017-01-01 23:59` and averages them

# %% [markdown]
# We can also get the total by adding the values

# %%
# The number of rows (365) hint that it was correct
bitcoin.resample('1D').sum()
# Out:
#                     Open          High  ...        Middle    USD Volume
# Date                                    ...
# 2017-01-01  1.412318e+06  1.412493e+06  ...  1.412324e+06  1.061594e+06
# 2017-01-02  1.463651e+06  1.463931e+06  ...  1.463664e+06  1.476088e+06
# 2017-01-03  1.474019e+06  1.474191e+06  ...  1.474026e+06  2.356241e+06
# 2017-01-04  1.559425e+06  1.560128e+06  ...  1.559500e+06  3.548748e+06
# 2017-01-05  1.521421e+06  1.522911e+06  ...  1.521352e+06  5.998187e+06
# ...                  ...           ...  ...           ...           ...
# 2017-12-27  2.252094e+07  2.254448e+07  ...  2.252002e+07  1.431533e+08
# 2017-12-28  2.053592e+07  2.057068e+07  ...  2.053625e+07  1.565894e+08
# 2017-12-29  2.093165e+07  2.095135e+07  ...  2.093184e+07  9.279851e+07
# 2017-12-30  1.940592e+07  1.943140e+07  ...  1.940271e+07  1.158837e+08
# 2017-12-31  1.911494e+07  1.913150e+07  ...  1.911480e+07  1.082456e+08
#
# [365 rows x 7 columns]

# %% [markdown]
# This operation was more useful for the `Volume` column, as it now sums up all of the entries for that day

# %% [markdown]
# We can see that `1070.013119` bitcoin (about $1,061,594 at the time) were traded on 01/01

# %% [markdown]
# In fact, there was another way to get this!
#
#     Multiply bitcoin per minute rate from before (0.743065) times the number of minute in a day (1440)

# %%
1440*0.743065
# Out:
# 1070.0136

# %% [markdown]
# ## Resampling TSD by Column

# %% [markdown]
# If we want the lowest or highest price for the whole day, we don't need an average or a sum!

# %% [markdown]
# We can tell Pandas to use `max` on these values, and also we can use `min` for `Low`

# %%
bitcoin.resample('1D').max()
# Out:
#                 Open      High       Low  ...      Volume     Middle    USD Volume
# Date                                      ...
# 2017-01-01   1003.54   1003.54   1003.54  ...  110.126689   1003.540  1.102911e+05
# 2017-01-02   1035.89   1035.90   1035.88  ...  116.627861   1035.885  1.197103e+05
# 2017-01-03   1038.26   1038.26   1038.26  ...  405.000039   1038.260  4.150481e+05
# 2017-01-04   1150.00   1155.54   1149.97  ...  167.000000   1149.980  1.839179e+05
# 2017-01-05   1167.16   1167.16   1167.16  ...  918.000000   1167.160  8.822990e+05
# ...              ...       ...       ...  ...         ...        ...           ...
# 2017-12-27  16500.00  16500.00  16499.58  ...  115.322939  16499.790  1.704437e+06
# 2017-12-28  15495.96  15499.99  15493.84  ...  143.885194  15494.420  2.005490e+06
# 2017-12-29  15077.92  15115.10  15060.75  ...  172.666517  15087.925  2.448388e+06
# 2017-12-30  14607.75  14607.77  14577.60  ...  168.027243  14592.685  2.205184e+06
# 2017-12-31  14180.00  14191.20  14163.09  ...  106.797334  14171.545  1.435948e+06
#
# [365 rows x 7 columns]

# %%
bitcoin.resample('1D').min()
# Out:
#                 Open      High       Low  ...  Volume     Middle  USD Volume
# Date                                      ...
# 2017-01-01    965.00    965.00    965.00  ...     0.0    965.000         0.0
# 2017-01-02    995.00    995.01    995.00  ...     0.0    995.010         0.0
# 2017-01-03   1014.34   1014.35   1014.06  ...     0.0   1014.345         0.0
# 2017-01-04   1035.03   1035.03   1035.02  ...     0.0   1035.030         0.0
# 2017-01-05    879.00    899.87    879.00  ...     0.0    892.365         0.0
# ...              ...       ...       ...  ...     ...        ...         ...
# 2017-12-27  14541.60  14599.62  14521.00  ...     0.0  14560.500         0.0
# 2017-12-28  13532.44  13579.80  13514.81  ...     0.0  13556.120         0.0
# 2017-12-29  13962.47  14000.02  13949.50  ...     0.0  13983.010         0.0
# 2017-12-30  12481.44  12508.19  12481.44  ...     0.0  12504.095         0.0
# 2017-12-31  12540.25  12555.11  12511.00  ...     0.0  12540.055         0.0
#
# [365 rows x 7 columns]

# %% [markdown]
# To generate a new dataframe with both changes applied to the respective column in one line of code, we will use the `resample`, `lambda` and `apply` methods:

# %% [markdown]
# - For `High`, we will `max` the values of `High` for each minute
#
# - For `Low`, we will use `min`
#
# - For `Volume` and `USD Volume`, we will use `sum`
#
# - For `Open`, we will use the **first** item (index `[0]`)
#
# - For `Close`, we will use the **last** item (index `[-1]`)

# %%
daily = bitcoin.resample('1D').apply({'Open'       : lambda x: x[0],
                                      'High'       : np.max,
                                      'Low'        : np.min,
                                      'Close'      : lambda x: x[-1],
                                      'Volume'     : np.sum,
                                      'USD Volume' : np.sum})
daily
# Out:
#                 Open      High       Low     Close        Volume    USD Volume
# Date
# 2017-01-01    974.55   1003.54    965.00    998.57   1070.013119  1.061594e+06
# 2017-01-02    998.57   1035.90    995.00   1020.23   1449.193752  1.476088e+06
# 2017-01-03   1020.23   1038.26   1014.06   1035.03   2298.844903  2.356241e+06
# 2017-01-04   1035.03   1155.54   1035.02   1143.16   3252.704150  3.548748e+06
# 2017-01-05   1143.16   1167.16    879.00   1004.84   6034.569411  5.998187e+06
# ...              ...       ...       ...       ...           ...           ...
# 2017-12-27  15830.86  16500.00  14521.00  15418.95   9255.819566  1.431533e+08
# 2017-12-28  15418.95  15499.99  13514.81  14488.61  11001.121472  1.565894e+08
# 2017-12-29  14488.61  15115.10  13949.50  14574.99   6391.623337  9.279851e+07
# 2017-12-30  14574.99  14607.77  12481.44  12675.68   8734.652933  1.158837e+08
# 2017-12-31  12675.68  14191.20  12511.00  13820.26   8176.382068  1.082456e+08
#
# [365 rows x 6 columns]

# %% [markdown]
# Notice that the `Close` of one day still matches the `Open` of the next

# %% [markdown]
# Moreover, we have deliberately left out `Middle` since we want to recalculate it on a daily basis, as it will be different from what we calculate on a minute basis!

# %% [markdown]
# We will leave the `USD Volume` based on minute data since that will give a more accurate estimate and this column is not exact since we don't have the trades list

# %% [markdown]
# Let's recalculate `Middle` on this new daily data

# %%
daily['Middle'] = (daily['High'] + daily['Low']) / 2
daily
# Out:
#                 Open      High       Low  ...        Volume    USD Volume     Middle
# Date                                      ...
# 2017-01-01    974.55   1003.54    965.00  ...   1070.013119  1.061594e+06    984.270
# 2017-01-02    998.57   1035.90    995.00  ...   1449.193752  1.476088e+06   1015.450
# 2017-01-03   1020.23   1038.26   1014.06  ...   2298.844903  2.356241e+06   1026.160
# 2017-01-04   1035.03   1155.54   1035.02  ...   3252.704150  3.548748e+06   1095.280
# 2017-01-05   1143.16   1167.16    879.00  ...   6034.569411  5.998187e+06   1023.080
# ...              ...       ...       ...  ...           ...           ...        ...
# 2017-12-27  15830.86  16500.00  14521.00  ...   9255.819566  1.431533e+08  15510.500
# 2017-12-28  15418.95  15499.99  13514.81  ...  11001.121472  1.565894e+08  14507.400
# 2017-12-29  14488.61  15115.10  13949.50  ...   6391.623337  9.279851e+07  14532.300
# 2017-12-30  14574.99  14607.77  12481.44  ...   8734.652933  1.158837e+08  13544.605
# 2017-12-31  12675.68  14191.20  12511.00  ...   8176.382068  1.082456e+08  13351.100
#
# [365 rows x 7 columns]

# %% [markdown]
# ## Plotting TSD

# %% [markdown]
# Typically, plots used for this type of data are line or candlestick plots

# %%
import plotly.express as px
fig = px.line(daily.reset_index(), x='Date', y='Middle')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a509ff9f-5bd6-4efc-b709-101e72d8b558" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a509ff9f-5bd6-4efc-b709-101e72d8b558")) {                    Plotly.newPlot(                        "a509ff9f-5bd6-4efc-b709-101e72d8b558",                        [{"hovertemplate":"Date=%{x}<br>Middle=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2017-01-01T00:00:00","2017-01-02T00:00:00","2017-01-03T00:00:00","2017-01-04T00:00:00","2017-01-05T00:00:00","2017-01-06T00:00:00","2017-01-07T00:00:00","2017-01-08T00:00:00","2017-01-09T00:00:00","2017-01-10T00:00:00","2017-01-11T00:00:00","2017-01-12T00:00:00","2017-01-13T00:00:00","2017-01-14T00:00:00","2017-01-15T00:00:00","2017-01-16T00:00:00","2017-01-17T00:00:00","2017-01-18T00:00:00","2017-01-19T00:00:00","2017-01-20T00:00:00","2017-01-21T00:00:00","2017-01-22T00:00:00","2017-01-23T00:00:00","2017-01-24T00:00:00","2017-01-25T00:00:00","2017-01-26T00:00:00","2017-01-27T00:00:00","2017-01-28T00:00:00","2017-01-29T00:00:00","2017-01-30T00:00:00","2017-01-31T00:00:00","2017-02-01T00:00:00","2017-02-02T00:00:00","2017-02-03T00:00:00","2017-02-04T00:00:00","2017-02-05T00:00:00","2017-02-06T00:00:00","2017-02-07T00:00:00","2017-02-08T00:00:00","2017-02-09T00:00:00","2017-02-10T00:00:00","2017-02-11T00:00:00","2017-02-12T00:00:00","2017-02-13T00:00:00","2017-02-14T00:00:00","2017-02-15T00:00:00","2017-02-16T00:00:00","2017-02-17T00:00:00","2017-02-18T00:00:00","2017-02-19T00:00:00","2017-02-20T00:00:00","2017-02-21T00:00:00","2017-02-22T00:00:00","2017-02-23T00:00:00","2017-02-24T00:00:00","2017-02-25T00:00:00","2017-02-26T00:00:00","2017-02-27T00:00:00","2017-02-28T00:00:00","2017-03-01T00:00:00","2017-03-02T00:00:00","2017-03-03T00:00:00","2017-03-04T00:00:00","2017-03-05T00:00:00","2017-03-06T00:00:00","2017-03-07T00:00:00","2017-03-08T00:00:00","2017-03-09T00:00:00","2017-03-10T00:00:00","2017-03-11T00:00:00","2017-03-12T00:00:00","2017-03-13T00:00:00","2017-03-14T00:00:00","2017-03-15T00:00:00","2017-03-16T00:00:00","2017-03-17T00:00:00","2017-03-18T00:00:00","2017-03-19T00:00:00","2017-03-20T00:00:00","2017-03-21T00:00:00","2017-03-22T00:00:00","2017-03-23T00:00:00","2017-03-24T00:00:00","2017-03-25T00:00:00","2017-03-26T00:00:00","2017-03-27T00:00:00","2017-03-28T00:00:00","2017-03-29T00:00:00","2017-03-30T00:00:00","2017-03-31T00:00:00","2017-04-01T00:00:00","2017-04-02T00:00:00","2017-04-03T00:00:00","2017-04-04T00:00:00","2017-04-05T00:00:00","2017-04-06T00:00:00","2017-04-07T00:00:00","2017-04-08T00:00:00","2017-04-09T00:00:00","2017-04-10T00:00:00","2017-04-11T00:00:00","2017-04-12T00:00:00","2017-04-13T00:00:00","2017-04-14T00:00:00","2017-04-15T00:00:00","2017-04-16T00:00:00","2017-04-17T00:00:00","2017-04-18T00:00:00","2017-04-19T00:00:00","2017-04-20T00:00:00","2017-04-21T00:00:00","2017-04-22T00:00:00","2017-04-23T00:00:00","2017-04-24T00:00:00","2017-04-25T00:00:00","2017-04-26T00:00:00","2017-04-27T00:00:00","2017-04-28T00:00:00","2017-04-29T00:00:00","2017-04-30T00:00:00","2017-05-01T00:00:00","2017-05-02T00:00:00","2017-05-03T00:00:00","2017-05-04T00:00:00","2017-05-05T00:00:00","2017-05-06T00:00:00","2017-05-07T00:00:00","2017-05-08T00:00:00","2017-05-09T00:00:00","2017-05-10T00:00:00","2017-05-11T00:00:00","2017-05-12T00:00:00","2017-05-13T00:00:00","2017-05-14T00:00:00","2017-05-15T00:00:00","2017-05-16T00:00:00","2017-05-17T00:00:00","2017-05-18T00:00:00","2017-05-19T00:00:00","2017-05-20T00:00:00","2017-05-21T00:00:00","2017-05-22T00:00:00","2017-05-23T00:00:00","2017-05-24T00:00:00","2017-05-25T00:00:00","2017-05-26T00:00:00","2017-05-27T00:00:00","2017 ...

# %%
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime

daily.reset_index(inplace=True)

fig = go.Figure(data=[go.Candlestick(x=daily['Date'], 
                open=daily['Open'],
                high=daily['High'],
                low=daily['Low'],
                close=daily['Close'])])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d9024dae-06b9-4155-aca2-0acf9e12e3e6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9024dae-06b9-4155-aca2-0acf9e12e3e6")) {                    Plotly.newPlot(                        "d9024dae-06b9-4155-aca2-0acf9e12e3e6",                        [{"close":[998.57,1020.23,1035.03,1143.16,1004.84,893.49,907.4,913.98,903.02,906.09,779.7,805.84,827.87,825.69,827.73,835.02,906.19,884.99,905.03,898.0,924.28,924.98,919.2,883.2,894.97,917.6,921.01,921.29,915.62,922.0,971.25,989.1,1007.32,1017.0,1032.99,1011.91,1023.99,1055.42,1053.9,988.7,1001.07,1013.57,1007.77,1000.97,1013.12,1013.67,1034.33,1059.75,1059.84,1054.72,1085.13,1133.68,1128.54,1181.02,1183.72,1148.77,1182.03,1194.5,1195.2,1228.9,1260.21,1287.98,1270.0,1273.99,1288.88,1236.29,1151.39,1197.2,1109.29,1182.64,1232.63,1246.85,1248.2,1261.75,1175.29,1070.6,965.1,1010.63,1041.61,1113.81,1037.97,1033.0,936.83,966.76,967.14,1045.01,1045.04,1041.03,1041.75,1084.22,1089.99,1107.45,1152.94,1149.03,1134.73,1195.77,1194.67,1184.5,1210.08,1210.64,1223.76,1218.12,1177.88,1175.5,1174.69,1178.01,1193.81,1204.0,1211.45,1238.45,1250.0,1247.66,1247.83,1255.71,1282.56,1294.91,1346.04,1347.19,1351.08,1362.63,1440.82,1464.94,1517.95,1550.0,1546.93,1580.99,1602.17,1686.39,1719.51,1793.26,1834.1,1694.64,1781.71,1794.01,1742.67,1769.71,1812.57,1895.55,1965.01,2044.4,2026.0,2101.33,2261.22,2436.45,2330.84,2267.37,2096.77,2230.77,2284.3,2197.33,2303.62,2412.34,2484.04,2554.91,2520.05,2689.43,2880.23,2690.0,2800.0,2807.01,2903.77,2960.0,2656.3,2716.06,2459.56,2416.16,2484.64,2638.24,2519.87,2594.99,2734.14,2645.1,2689.58,2684.63,2572.96,2497.6,2415.62,2573.77,2554.97,2549.89,2456.01,2416.12,2507.84,2540.94,2606.64,2625.06,2605.53,2493.79,2547.77,2501.02,2329.4,2305.05,2383.82,2343.48,2213.01,1967.34,1904.0,2229.07,2304.36,2264.29,2889.98,2661.99,2838.07,2761.45,2758.5,2558.27,2524.52,2662.99,2786.19,2706.14,2749.99,2871.27,2730.0,2703.44,2783.43,2844.99,3252.34,3218.73,3391.48,3421.11,3348.99,3421.45,3639.99,3863.3,4046.34,4318.3,4154.84,4340.01,4284.45,4102.48,4145.11,4049.98,3993.87,4093.28,4147.1,4313.21,4371.25,4371.25,4340.88,4379.97,4589.99,4583.85,4736.28,4924.0,4642.85,4607.47,4278.86,4393.0,4609.17,4623.19,4346.24,4325.17,4243.48,4209.69,4155.55,3855.01,3242.63,3709.85,3715.38,3716.46,4098.03,3903.4,3866.0,3616.74,3620.96,3783.6,3667.99,3916.48,3885.14,4204.51,4188.0,4182.89,4327.63,4388.74,4385.7,4300.0,4214.25,4318.57,4362.42,4425.01,4602.5,4751.08,4756.22,4813.85,5437.68,5636.28,5799.99,5694.61,5748.56,5592.26,5569.33,5695.01,5984.03,6012.58,5974.97,5899.6,5517.21,5741.66,5889.42,5765.32,5730.01,6132.76,6124.69,6448.36,6741.02,7037.48,7150.58,7371.55,7394.44,6975.01,7109.7,7465.53,7151.49,6585.11,6340.0,5849.37,6549.3,6606.75,7292.65,7852.44,7677.17,7776.54,8046.98,8246.01,8120.36,8240.82,8009.88,8209.88,8779.62,9306.21,9763.11,9941.7,9827.29,9934.4,10910.18,10888.01,11231.21,11668.84,11711.2,13735.16,17050.0,16250.01,15041.0,15268.98,16800.19,17382.19,16460.9,16678.79,17744.5,19499.99,19260.5,18983.0,17640.01,16596.09,15800.0,14000.0,15002.72,14100.01,13986.68,15830.86,15418.95,14488.61,14574.99,12675.68,13820.26],"high":[1003.54,1035.9,1038.26,1155.54,1167.16,1025.56,908.76,940.1,913.98,913.99,924.02,832.15,833.79,839.78,829.58,841.28,910.99,916.89,908.97,906.56,928.97,940.42,928.0,925.09,903.02,920.59,924.88,922.99,922.99,923.99,971.68,990.0,1013.92,1024.0,1041.97,1032.99,1028.12,1055.42,1071.3,1079.99,1009.09,1020.43,1013.99,1014.99,1020.01,1015.57,1042.14,1063.99,1069.23,1062.2,1085.13,1134.59,1140.0,1193.99,1213.39,1186.69,1185.99,1201.03,1214.96,1230.0,1285.1,1293.35,1287.99,1275.0,1288.98,1288.89,1245.99,1211.82,1325.0,1197.72,1237.68,1250.0,1258.48,1265.0,1263.11,1175.29,1097.68,1060.0 ...

# %% [markdown]
# However, if we had the data of one more cryptocurrency (yes, there's [more crypto other than bitcoin!](https://coinmarketcap.com/all/views/all/)), we could compare their trends and see which one is trading higher!

# %% [markdown]
# And that is why people came up with... the BAR CHART RACE (BCR)!

# %% [markdown]
# ![Fig 1.](https://www.dropbox.com/s/crvqd8tjjywboma/barchartrace.gif?raw=1)

# %% [markdown]
# Let's see how this example was produced using Python

# %% [markdown]
# We will use a file called `city_populations.txt` which you can download from [here](https://gist.githubusercontent.com/johnburnmurdoch/4199dbe55095c3e13de8d5b2e5e5307a/raw/fa018b25c24b7b5f47fd0568937ff6c04e384786/city_populations)

# %% [markdown]
# This file contains population data of different world cities through time

# %%
df = pd.read_csv('https://gist.githubusercontent.com/johnburnmurdoch/4199dbe55095c3e13de8d5b2e5e5307a/raw/fa018b25c24b7b5f47fd0568937ff6c04e384786/city_populations')
df
# Out:
#              name  group  year  ...  lastValue       lat       lon
# 0            Agra  India  1575  ...      200.0  27.18333  78.01667
# 1            Agra  India  1576  ...      200.0  27.18333  78.01667
# 2            Agra  India  1577  ...      212.0  27.18333  78.01667
# 3            Agra  India  1578  ...      224.0  27.18333  78.01667
# 4            Agra  India  1579  ...      236.0  27.18333  78.01667
# ...           ...    ...   ...  ...        ...       ...       ...
# 6247  Vijayanagar  India  1561  ...      480.0  15.33500  76.46200
# 6248  Vijayanagar  India  1562  ...      480.0  15.33500  76.46200
# 6249  Vijayanagar  India  1563  ...      480.0  15.33500  76.46200
# 6250  Vijayanagar  India  1564  ...      480.0  15.33500  76.46200
# 6251  Vijayanagar  India  1565  ...      480.0  15.33500  76.46200
#
# [6252 rows x 9 columns]

# %% [markdown]
# Let's clean this a little bit...

# %%
# These are the only columns we need
df = df[['name','group','year','value']]
df
# Out:
#              name  group  year  value
# 0            Agra  India  1575  200.0
# 1            Agra  India  1576  212.0
# 2            Agra  India  1577  224.0
# 3            Agra  India  1578  236.0
# 4            Agra  India  1579  248.0
# ...           ...    ...   ...    ...
# 6247  Vijayanagar  India  1561  480.0
# 6248  Vijayanagar  India  1562  480.0
# 6249  Vijayanagar  India  1563  480.0
# 6250  Vijayanagar  India  1564  480.0
# 6251  Vijayanagar  India  1565  480.0
#
# [6252 rows x 4 columns]

# %% [markdown]
# We will change the names of the columns to something more coherent!

# %%
df = df.rename(columns={"name": "City", "group": "Continent","year": "Year", "value":"Population"})
df
# Out:
#              City Continent  Year  Population
# 0            Agra     India  1575       200.0
# 1            Agra     India  1576       212.0
# 2            Agra     India  1577       224.0
# 3            Agra     India  1578       236.0
# 4            Agra     India  1579       248.0
# ...           ...       ...   ...         ...
# 6247  Vijayanagar     India  1561       480.0
# 6248  Vijayanagar     India  1562       480.0
# 6249  Vijayanagar     India  1563       480.0
# 6250  Vijayanagar     India  1564       480.0
# 6251  Vijayanagar     India  1565       480.0
#
# [6252 rows x 4 columns]

# %% [markdown]
# Notice that in the `Continent` column we have India for some cities

# %% [markdown]
# If I'm correct, India is a sub-continent rather than a continent!

# %% [markdown]
# Let's see the continents listed here...

# %%
set(df['Continent'])
# Out:
# {'Asia', 'Europe', 'India', 'Latin America', 'Middle East', 'North America'}

# %% [markdown]
# Middle East and Latin America are also listed as continents!

# %%
# Cities in the "Indian continent"
print(set(df[df['Continent']=='India']['City']))
# Out:
# {'Vijayanagar', 'Ahmedabad', 'Bijapur', 'Mumbai', 'Kolkatta', 'Lucknow', 'Delhi', 'Agra', 'Gauda', 'Cuttack'}

# %%
# Cities with "Middle East" continent
print(set(df[df['Continent']=='Middle East']['City']))
# Out:
# {'Fez', 'Esfahan', 'Tabriz', 'Mashhad', 'Cairo'}

# %%
# Cities with "Latin America" continent
print(set(df[df['Continent']=='Latin America']['City']))
# Out:
# {'Mexico City', 'Sao Paulo', 'Buenos Aires', 'Rio de Janeiro'}

# %% [markdown]
# Let's first replace `India -> Asia`

# %%
df['Continent'] = df['Continent'].replace('India', 'Asia')
df
# Out:
#              City Continent  Year  Population
# 0            Agra      Asia  1575       200.0
# 1            Agra      Asia  1576       212.0
# 2            Agra      Asia  1577       224.0
# 3            Agra      Asia  1578       236.0
# 4            Agra      Asia  1579       248.0
# ...           ...       ...   ...         ...
# 6247  Vijayanagar      Asia  1561       480.0
# 6248  Vijayanagar      Asia  1562       480.0
# 6249  Vijayanagar      Asia  1563       480.0
# 6250  Vijayanagar      Asia  1564       480.0
# 6251  Vijayanagar      Asia  1565       480.0
#
# [6252 rows x 4 columns]

# %% [markdown]
# With the other two is slightly different, as these categories contain cities from different continents!

# %% [markdown]
# In fact, I may need to change "one by one"

# %%
# It shows a warning, but it works!
df['Continent'][df['City']=='Fez']='Africa'
df['Continent'][df['City']=='Cairo']='Africa'
df['Continent'] = df['Continent'].replace('Middle East', 'Asia')
df['Continent'][df['City']=='Mexico City']='North America'
df['Continent'] = df['Continent'].replace('Latin America', 'South America')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Show that the replacement has been successful
df[df['City']=='Mexico City'] # try looking at other cities
# Out:
#              City      Continent  Year  Population
# 3508  Mexico City  North America  1952      3736.6
# 3509  Mexico City  North America  1953      3922.4
# 3510  Mexico City  North America  1954      4108.2
# 3511  Mexico City  North America  1955      4294.0
# 3512  Mexico City  North America  1956      4531.0
# ...           ...            ...   ...         ...
# 3572  Mexico City  North America  2016     21172.8
# 3573  Mexico City  North America  2017     21346.6
# 3574  Mexico City  North America  2018     21520.4
# 3575  Mexico City  North America  2019     21694.2
# 3576  Mexico City  North America  2020     21868.0
#
# [69 rows x 4 columns]

# %% [markdown]
# I will save the new dataset locally

# %%
df.to_csv(r'city_populations_updated.csv',index=False)

# %% [markdown]
# Now, let's try to do our own BCR with `Python` and the `matplotlib` package

# %%
# Importing the necessary packages
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %% [markdown]
# If we just plot **city vs population** using `ax.barh`, we will see the last value of population for each of the cities

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(df['City'], df['Population'])
# Out:
# <BarContainer object of 6252 artists>

# %% [markdown]
# To do a BCR, we need to define a given year and sort the cities from most to least populated (for that year)

# %%
current_year = 1900
df2 = (df[df['Year'].eq(current_year)]
       .sort_values(by='Population',ascending=False))
df2
# Out:
#                   City      Continent  Year  Population
# 3246            London         Europe  1900      6480.0
# 4209          New York  North America  1900      4242.0
# 5082             Paris         Europe  1900      3330.0
# 747             Berlin         Europe  1900      2707.0
# 1215           Chicago  North America  1900      1717.0
# 6158            Vienna         Europe  1900      1698.0
# 5927             Tokyo           Asia  1900      1497.0
# 5384  Saint Petersburg         Europe  1900      1439.0
# 3431        Manchester         Europe  1900      1435.0
# 5232      Philadelphia  North America  1900      1418.0
# 937         Birmingham         Europe  1900      1248.0
# 3592            Moscow         Europe  1900      1120.0

# %% [markdown]
# Notice that in this dataset, we don't have all cities for each year so we would get different charts

# %%
# Plotting a basic bar chart
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(df2['City'], df2['Population'])
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# To add colours and labels (for each continent), we will use a dictionary that pairs cities with their respective continent

# %%
colours = dict(zip(
    ['Europe', 'Asia', 'South America', 'North America', 'Africa'],
    ['#adb0ff', '#90d595','#aafbff', '#f7bb5f', '#eafb50']))
group_lk = df.set_index('City')['Continent'].to_dict()
group_lk
# Out:
# {'Agra': 'Asia',
#  'Ahmedabad': 'Asia',
#  'Amsterdam': 'Europe',
#  'Ayutthaya': 'Asia',
#  'Beijing': 'Asia',
#  'Berlin': 'Europe',
#  'Bijapur': 'Asia',
#  'Birmingham': 'Europe',
#  'Boston': 'North America',
#  'Buenos Aires': 'South America',
#  'Cairo': 'Africa',
#  'Chicago': 'North America',
#  'Cuttack': 'Asia',
#  'Delhi': 'Asia',
#  'Dhaka': 'Asia',
#  'Edirne': 'Europe',
#  'Esfahan': 'Asia',
#  'Fez': 'Africa',
#  'Gauda': 'Asia',
#  'Guangzhou': 'Asia',
#  'Hangzhou': 'Asia',
#  'Istanbul': 'Europe',
#  'Karachi': 'Asia',
#  'Kolkatta': 'Asia',
#  'Kyoto': 'Asia',
#  'Lisbon': 'Europe',
#  'London': 'Europe',
#  'Los Angeles': 'North America',
#  'Lucknow': 'Asia',
#  'Manchester': 'Europe',
#  'Mashhad': 'Asia',
#  'Mexico City': 'North America',
#  'Moscow': 'Europe',
#  'Mumbai': 'Asia',
#  'Nanjing': 'Asia',
#  'Naples': 'Europe',
#  'New York': 'North America',
#  'Osaka': 'Asia',
#  'Paris': 'Europe',
#  'Pegu': 'Asia',
#  'Philadelphia': 'North America',
#  'Rio de Janeiro': 'South America',
#  'Saint Petersburg': 'Europe',
#  'Sao Paulo': 'South America',
#  'Seoul': 'Asia',
#  'Shanghai': 'Asia',
#  'Suzhou': 'Asia',
#  'Tabriz': 'Asia',
#  'Tokyo': 'Asia',
#  'Venice': 'Europe',
#  'Vienna': 'Europe',
#  'Vijayanagar': 'Asia'}

# %% [markdown]
# Now we can use this pairing to get some colours in `df2`

# %%
fig, ax = plt.subplots(figsize=(15, 8))
df2 = df2[::-1]   # flip values from top to bottom
# pass colours values to `color=`
ax.barh(df2['City'], df2['Population'], color=[colours[group_lk[x]] for x in df2['City']])
# iterate over the values to plot labels and values (Tokyo, Asia, 38194.2)
for i, (value, name) in enumerate(zip(df2['Population'], df2['City'])):
    ax.text(value, i,     name,            ha='right')
    ax.text(value, i-.25, group_lk[name],  ha='right')
    ax.text(value, i,     value,           ha='left')
# Add year right middle portion of canvas
ax.text(1, 0.4, current_year, transform=ax.transAxes, size=46, ha='right')
# Out:
# Text(1, 0.4, '1900')

# %% [markdown]
# This function will draw a more "stylish" function to create the last chart

# %%
# Frankly, I don't know what half of it does...
def draw_barchart(year):
    dff = df[df['Year'].eq(year)].sort_values(by='Population', ascending=True).tail(10)
    ax.clear()
    ax.barh(dff['City'], dff['Population'], color=[colours[group_lk[x]] for x in dff['City']])
    dx = dff['Population'].max() / 200
    for i, (value, name) in enumerate(zip(dff['Population'], dff['City'])):
        ax.text(value-dx, i,     name,           size=14, weight=600, ha='right', va='bottom')
        ax.text(value-dx, i-.25, group_lk[name], size=10, color='#444444', ha='right', va='baseline')
        ax.text(value+dx, i,     f'{value:,.0f}',  size=14, ha='left',  va='center')
    # ... polished styles
    ax.text(1, 0.4, year, transform=ax.transAxes, color='#777777', size=46, ha='right', weight=800)
    ax.text(0, 1.06, 'Population (thousands)', transform=ax.transAxes, size=12, color='#777777')
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
    ax.xaxis.set_ticks_position('top')
    ax.tick_params(axis='x', colors='#777777', labelsize=12)
    ax.set_yticks([])
    ax.margins(0, 0.01)
    ax.grid(which='major', axis='x', linestyle='-')
    ax.set_axisbelow(True)
    ax.text(0, 1.12, 'The most populous cities in the world ',
            transform=ax.transAxes, size=24, weight=600, ha='left')
    plt.box(False)

# %%
# Now we execute the function
fig, ax = plt.subplots(figsize=(15, 8))
draw_barchart(2000)

# %% [markdown]
# The most important part is to animate the plot for a range of years

# %%
import matplotlib.animation as animation
from IPython.display import HTML
fig, ax = plt.subplots(figsize=(15, 8))
animator = animation.FuncAnimation(fig, draw_barchart, frames=range(1990,2020))
HTML(animator.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdc8941208d53403e88fca0ae5bfa93a9">
#   <div class="anim-controls">
#     <input id="_anim_sliderdc8941208d53403e88fca0ae5bfa93a9" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdc8941208d53403e88fca0ae5bfa93a9.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animdc8941208d53403e88fca0ae5bfa93a9.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectdc8941208d53403e88fca0ae5bfa93a9" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_dc8941208d53403e88fca0ae5bfa93a9"
#              >
#       <label for="_anim_radio1_dc8941208d53403e88fca0ae5bfa93a9">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_dc8941208d53403e88fca0ae5bfa93a9"
#              checked>
#       <label for="_anim_radio2_dc8941208d53403e88fca0ae5bfa93a9">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_dc8941208d53403e88fca0ae5bfa93a9"
#              >
#       <label for="_anim_radio3_dc8941208d53403e88fca0ae5bfa93a9">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdc8941208d53403e88fca0ae5bfa93a9";
#     var slider_id = "_anim_sliderdc8941208d53403e88fca0ae5bfa93a9";
#     var loop_select_id = "_anim_loop_selectdc8941208d53403e88fca0ae5bfa93a9";
#     var frames = new Array(30);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nOzdd1gU1/4/8Pcuy9KLdBAFsYBSVMSG\
# ohh71xtLTBQ1mmg0iSkaU0w0MeYak3sT4zVqmjWxxx67oghREUXsokJsgBQBacuyO78/+Llfhl2q\
# wLLyfj0PT9w5Zc7MHE7gw5lzIBCVwcPDQwBQ7a/jx48LgiAIEydOFB2fOHGiXq+roerZs6foOcyf\
# P1/fTXpuHD9+XKv/U+VU1C8TEhK07m1CQkKZ9ZU1DhmC0mPu6tWr9dKOqowVHN/r1vz580X3u2fP\
# nlWug+MVERE9z2QgIiLSk02bNqGgoEDz2dbW9pnqS0hIEH12cXF5pvrq0qlTp1BUVKT57ODgoMfW\
# EBERERkeBjioTKV/2H6qWbNmos+zZs3CO++8o5XPkH6xICL9qOlxwtPTs0brq0vu7u76bgIRERGR\
# QZPquwFUf7m7u8PT01PrqzRbW1

# %%
## Save the animation
writergif = animation.PillowWriter(fps=30) 
animator.save(r"animation.gif" , writer=writergif)

# %% [markdown]
# ## Lab

# %% [markdown]
# There are two parts, one for TSD and another for BCR

# %% [markdown]
# The first one consists on following the instructions to treat TSD data

# %% [markdown]
# The second one has the code seen in class to do the BCR

# %% [markdown]
# For that one, I want you to get creative!
#    - Can you change colours, styles, names, etc.?
#    - Can you skip some years?
#    - Can you get rid of the static plot that gets printed after the animation?
#    - Can you show not only the top 12 cities?
#    - Can you show all cities at the same time?
#    - Can you put the years of the range in the title of the chart?
#    - Can you run it from 1500 to 2020?
#    - Can you make the chart go back in time?

# %% [markdown]
# Alternatively you can download the dataset from Moodle and see if other tools are able to these things!
# * You can try to install [this Python Module](https://pypi.org/project/bar-chart-race/) which in fact looks easier and better than my proposed method!
# * Using [an app by Microsoft](https://appsource.microsoft.com/en-us/product/power-bi-visuals/WA200000053?tab=Overview)
# * Using online services such as [Fluorish](https://app.flourish.studio/@flourish/bar-chart-race) or [Highcharts](https://www.highcharts.com/blog/tutorials/bar-chart-race/)
# * Or with [Excel](https://help.xlstat.com/s/article/bar-chart-race-tutorial-in-excel?language=en_US)!
